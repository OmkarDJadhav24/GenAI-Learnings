# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Sample input: 3 sequences with different lengths
sentences = [
    [1, 2, 3, 4],       # no padding needed
    [5, 6, 7],          # will need 1 pad
    [8, 9]              # will need 2 pads
]

# Pad the sequences
padded = pad_sequences(sentences, maxlen=4, padding='post')
print("Padded Sequences:\n", padded)

# Create model with mask-aware embedding
model = Sequential()
model.add(Embedding(input_dim=10, output_dim=4, input_length=4, mask_zero=True))
model.add(LSTM(units=4))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy')
model.summary()

# Dummy labels (binary classification)
labels = np.array([1, 0, 1])

# Train model
model.fit(padded, labels, epochs=2)
# Out:
# 2025-05-26 21:17:19.827473: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-05-26 21:17:19.944052: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-05-26 21:17:20.043288: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748274440.111071    4249 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748274440.133453    4249 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
